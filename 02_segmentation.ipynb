# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
import pandas as pd
df = pd.read_csv("data/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df = df.dropna()
df = df.select_dtypes(include=['float64', 'int64'])  # Focus on numeric columns

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(scaled_data)
df['Cluster'] = kmeans.labels_

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print(df.columns)
sns.pairplot(df[['tenure', 'MonthlyCharges', 'Cluster']], hue='Cluster')
plt.show()
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'Cluster'], dtype='object')

# %%
# Step 1: Select features for clustering
X = df[['tenure', 'MonthlyCharges', 'TotalCharges']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Step 1: Select features for clustering
# ----> 2 X = df[['tenure', 'MonthlyCharges', 'TotalCharges']]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
# ...

# %%
print([col for col in df.columns if 'totalcharges' in col.lower().replace(" ", "")])
# Out:
# []

# %%
# Check exact column names
print(df.columns.tolist())

# Strip any spaces around column names just in case
df.columns = df.columns.str.strip()

# Now select the features
X = df[['tenure', 'MonthlyCharges', 'TotalCharges']]
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'Cluster']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 8
#       5 df.columns = df.columns.str.strip()
#       7 # Now select the features
# ----> 8 X = df[['tenure', 'MonthlyCharges', 'TotalCharges']]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
import pandas as pd
df = pd.read_csv('cleaned_telco_data.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df[['tenure', 'MonthlyCharges', 'TotalCharges', 'Cluster']], hue='Cluster')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 3
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.pairplot(df[['tenure', 'MonthlyCharges', 'TotalCharges', 'Cluster']], hue='Cluster')
#       4 plt.show()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
import pandas as pd

# Load raw data
df = pd.read_csv("data/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Clean the data (repeat your original steps)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')  # Convert to numeric
df.dropna(inplace=True)  # Remove rows with missing TotalCharges
df.drop('customerID', axis=1, inplace=True)  # Drop ID column

# %%
X = df[['tenure', 'MonthlyCharges', 'TotalCharges']]

# %%
df = pd.read_csv("data/cleaned_telco.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df[['tenure', 'MonthlyCharges', 'TotalCharges', 'Cluster']], hue='Cluster')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 3
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.pairplot(df[['tenure', 'MonthlyCharges', 'TotalCharges', 'Cluster']], hue='Cluster')
#       4 plt.show()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
# Step 1: Select features for clustering
X = df[['tenure', 'MonthlyCharges', 'TotalCharges']]

# %%
# Step 2: Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Step 3: Apply KMeans clustering
kmeans = KMeans(n_clusters=4, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# %%
# Step 4: See how clusters are distributed
df['Cluster'].value_counts()
# Out:
# Cluster
# 3    2269
# 0    1915
# 1    1695
# 2    1153
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df[['tenure', 'MonthlyCharges', 'TotalCharges', 'Cluster']], hue='Cluster')
plt.show()
